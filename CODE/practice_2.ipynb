# %%
C:\Users\RAZER\Documents\GitHub\R_is_ON\R_exercise_Data\R_exercise\apple_hair.txt

C:\Users\RAZER\Documents\GitHub\R_is_ON\R_exercise_Data\R_exercise\bmi.txt

C:\Users\RAZER\Documents\GitHub\R_is_ON\R_exercise_Data\R_exercise\stroke_CI.xlsx

# %%
#ANOVA#############################
# get summary & structure and create a boxplot of our differences
head(chickwts)
str(chickwts)
summary(chickwts)

with(chickwts,boxplot(weight~feed,
                      col= "lightgray",
                      main= "",
                      xlab= "Feed type", ylab= "Weight (g)", ylim= c(100,450), las= 1)) 

aov1<-aov(weight~feed, data=chickwts) #Standard one-way ANOVA (assumes equal variances)
# Out:
#   weight feed
# 1 179    horsebean
# 2 160    horsebean
# 3 136    horsebean
# 4 227    horsebean
# 5 217    horsebean
# 6 168    horsebean
# 'data.frame':	71 obs. of  2 variables:
#  $ weight: num  179 160 136 227 217 168 108 124 143 140 ...
#  $ feed  : Factor w/ 6 levels "casein","horsebean",..: 2 2 2 2 2 2 2 2 2 2 ...
#      weight             feed
#  Min.   :108.0   casein   :12
#  1st Qu.:204.5   horsebean:10
#  Median :258.0   linseed  :12
#  Mean   :261.3   meatmeal :11
#  3rd Qu.:323.5   soybean  :14
#  Max.   :423.0   sunflower:12
# Call:
#    aov(formula = weight ~ feed, data = chickwts)
#
# Terms:
#                     feed Residuals
# Sum of Squares  231129.2  195556.0
# Deg. of Freedom        5        65
#
# Residual standard error: 54.85029
# Estimated effects may be unbalanced
# 	Shapiro-Wilk normality test
#
# data:  aov1$residuals
# W = 0.98616, p-value = 0.6272
# Plot with title ""

# %%
shapiro.test(aov1$residuals)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  aov1$residuals
# W = 0.98616, p-value = 0.6272

# %%
bartlett.test(weight ~ feed, data=chickwts)
# Out:
# 	Bartlett test of homogeneity of variances
#
# data:  weight by feed
# Bartlett's K-squared = 3.2597, df = 5, p-value = 0.66

# %%
summary(aov1) #F table
# Out:
#             Df Sum Sq Mean Sq F value   Pr(>F)
# feed         5 231129   46226   15.37 5.94e-10 ***
# Residuals   65 195556    3009
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %%
model.tables(aov1,type="mean")
# Out:
# Tables of means
# Grand mean
#
# 261.3099
#
#  feed
#     casein horsebean linseed meatmeal soybean sunflower
#      323.6     160.2   218.8    276.9   246.4     328.9
# rep   12.0      10.0    12.0     11.0    14.0      12.0

# %%
TukeyHSD(aov1) #multiple comparion (TukeyHSD)
par(las=1, mai=c(1,2,1,1))
plot(TukeyHSD(aov1))
# Out:
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = weight ~ feed, data = chickwts)
#
# $feed
#                            diff         lwr       upr     p adj
# horsebean-casein    -163.383333 -232.346876 -94.41979 0.0000000
# linseed-casein      -104.833333 -170.587491 -39.07918 0.0002100
# meatmeal-casein      -46.674242 -113.906207  20.55772 0.3324584
# soybean-casein       -77.154762 -140.517054 -13.79247 0.0083653
# sunflower-casein       5.333333  -60.420825  71.08749 0.9998902
# linseed-horsebean     58.550000  -10.413543 127.51354 0.1413329
# meatmeal-horsebean   116.709091   46.335105 187.08308 0.0001062
# soybean-horsebean     86.228571   19.541684 152.91546 0.0042167
# sunflower-horsebean  168.716667   99.753124 237.68021 0.0000000
# meatmeal-linseed      58.159091   -9.072873 125.39106 0.1276965
# soybean-linseed       27.678571  -35.683721  91.04086 0.7932853
# sunflower-linseed    110.166667   44.412509 175.92082 0.0000884
# soybean-meatmeal     -30.480519  -95.375109  34.41407 0.7391356
# sunflower-meatmeal    52.007576  -15.224388 119.23954 0.2206962
# sunflower-soybean     82.488095   19.125803 145.85039 0.0038845
# Plot with title "95% family-wise confidence level
# "

# %%
boxplot(weight~feed, data=chickwts)
# Out:
# plot without title

# %%
avg<-aggregate(weight~feed, data=chickwts,FUN=mean)
plot(seq(1,6),avg[,2],type="b", xlab="", ylab="weight",xaxt="n", col=4)
axis(side=1, at=1:6, labels=avg[,1])
# Out:
# plot without title

# %%
#ggplot2
library(ggplot2)
ggplot(data=chickwts, aes(x=feed, y=weight, fill=feed)) +geom_boxplot() +labs(title ="chick feed weight Experiment") +theme_minimal()
# Out:
# plot without title

# %%
kruskal.test(weight~feed,data=chickwts)
# Out:
# 	Kruskal-Wallis rank sum test
#
# data:  weight by feed
# Kruskal-Wallis chi-squared = 37.343, df = 5, p-value = 5.113e-07

# %%
install.packages("FSA")
# Out:
# also installing the dependencies 'rbibutils', 'cowplot', 'Deriv', 'microbenchmark', 'Rdpack', 'doBy', 'SparseM', 'MatrixModels', 'minqa', 'nloptr', 'reformulas', 'carData', 'abind', 'Formula', 'pbkrtest', 'quantreg', 'lme4', 'car', 'dunn.test', 'FlexParamCurve', 'lmtest', 'plotrix'
# package 'rbibutils' successfully unpacked and MD5 sums checked
# package 'cowplot' successfully unpacked and MD5 sums checked
# package 'Deriv' successfully unpacked and MD5 sums checked
# package 'microbenchmark' successfully unpacked and MD5 sums checked
# package 'Rdpack' successfully unpacked and MD5 sums checked
# package 'doBy' successfully unpacked and MD5 sums checked
# package 'SparseM' successfully unpacked and MD5 sums checked
# package 'MatrixModels' successfully unpacked and MD5 sums checked
# package 'minqa' successfully unpacked and MD5 sums checked
# package 'nloptr' successfully unpacked and MD5 sums checked
# package 'reformulas' successfully unpacked and MD5 sums checked
# package 'carData' successfully unpacked and MD5 sums checked
# package 'abind' successfully unpacked and MD5 sums checked
# package 'Formula' successfully unpacked and MD5 sums checked
# package 'pbkrtest' successfully unpacked and MD5 sums checked
# package 'quantreg' successfully unpacked and MD5 sums checked
# package 'lme4' successfully unpacked and MD5 sums checked
# package 'car' successfully unpacked and MD5 sums checked
# package 'dunn.test' successfully unpacked and MD5 sums checked
# package 'FlexParamCurve' successfully unpacked and MD5 sums checked
# package 'lmtest' successfully unpacked and MD5 sums checked
# package 'plotrix' successfully unpacked and MD5 sums checked
# package 'FSA' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\RAZER\AppData\Local\Temp\RtmpaAGaBh\downloaded_packages

# %%
library(FSA)
dunnTest(weight~feed, data=chickwts, method = "bonferroni")#multiple comparion
# Out:
# ## FSA v0.10.0. See citation('FSA') if used in publication.
# ## Run fishR() for related website and fishR('IFAR') for related book.
# Dunn (1964) Kruskal-Wallis multiple comparison
#
#   p-values adjusted with the Bonferroni method.
#               Comparison          Z      P.unadj        P.adj
# 1     casein - horsebean  4.8130692 1.486298e-06 2.229447e-05
# 2       casein - linseed  3.3082926 9.386670e-04 1.408000e-02
# 3    horsebean - linseed -1.6587360 9.716899e-02 1.000000e+00
# 4      casein - meatmeal  1.4157560 1.568470e-01 1.000000e+00
# 5   horsebean - meatmeal -3.3640591 7.680508e-04 1.152076e-02
# 6     linseed - meatmeal -1.8198180 6.878673e-02 1.000000e+00
# 7       casein - soybean  2.4999221 1.242206e-02 1.863309e-01
# 8    horsebean - soybean -2.6020934 9.265660e-03 1.389849e-01
# 9      linseed - soybean -0.9332554 3.506881e-01 1.000000e+00
# 10    meatmeal - soybean  0.9741450 3.299846e-01 1.000000e+00
# 11    casein - sunflower -0.1829698 8.548217e-01 1.000000e+00
# 12 horsebean - sunflower -4.9875241 6.115798e-07 9.173698e-06
# 13   linseed - sunflower -3.4912624 4.807439e-04 7.211158e-03
# 14  meatmeal - sunflower -1.5947040 1.107784e-01 1.000000e+00
# 15   soybean - sunflower -2.6897988 7.149510e-03 1.072427e-01

# %%
#oneway.test : Welch’s ANOVA (used when variances are unequal)
oneway.test(weight ~ feed, data = chickwts)
# Out:
# 	One-way analysis of means (not assuming equal variances)
#
# data:  weight and feed
# F = 19.662, num df = 5.000, denom df = 29.952, p-value = 1.177e-08

# %%
#lm(): General linear model framework; basis for aov() and regression
lm1<-lm(weight ~ feed, data = chickwts)
summary(lm1)
# Out:
# Call:
# lm(formula = weight ~ feed, data = chickwts)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -123.909  -34.413    1.571   38.170  103.091
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)    323.583     15.834  20.436  < 2e-16 ***
# feedhorsebean -163.383     23.485  -6.957 2.07e-09 ***
# feedlinseed   -104.833     22.393  -4.682 1.49e-05 ***
# feedmeatmeal   -46.674     22.896  -2.039 0.045567 *
# feedsoybean    -77.155     21.578  -3.576 0.000665 ***
# feedsunflower    5.333     22.393   0.238 0.812495
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 54.85 on 65 degrees of freedom
# Multiple R-squared:  0.5417,	Adjusted R-squared:  0.5064
# F-statistic: 15.36 on 5 and 65 DF,  p-value: 5.936e-10

# %% [markdown]
# # Exercize 1

# %%
C:\Users\RAZER\Documents\GitHub\R_is_ON\R_exercise_Data\R_exercise\stroke_CI.xlsx

# %%
library(readxl)
library(tidyverse)

dat <- read_excel("C:/Users/RAZER/Documents/GitHub/R_is_ON/R_exercise_Data/R_exercise/stroke_CI.xlsx")

# %%
#1. Summary statistics
summary(dat$weight)
mean(dat$weight, na.rm = TRUE)
sd(dat$weight,   na.rm = TRUE)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   39.00   56.00   62.00   62.74   70.00  165.00
# [1] 62.74188
# [1] 10.92442

# %%
# 2. Normality Check
# Histogram + density
hist(dat$weight, breaks = 20, main = "Histogram of Body Weight", xlab = "Weight (kg)")
# Out:
# Plot with title "Histogram of Body Weight"

# %%
# QQ plot
 qqnorm(dat$weight);qqline(dat$weight,col = 2)
# Out:
# Plot with title "Normal Q-Q Plot"

# %%
# Shapiro–Wilk test (normality test)
shapiro.test(dat$weight)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  dat$weight
# W = 0.88858, p-value < 2.2e-16

# %%
t.test(dat$weight,mu=60,alternative = "greater")
# Out:
# 	One Sample t-test
#
# data:  dat$weight
# t = 5.0197, df = 399, p-value = 3.906e-07
# alternative hypothesis: true mean is greater than 60
# 95 percent confidence interval:
#  61.84133      Inf
# sample estimates:
# mean of x
#  62.74188

# %%
wilcox.test(dat$weight, mu=60, alternative="greater")
# Out:
# 	Wilcoxon signed rank test with continuity correction
#
# data:  dat$weight
# V = 45048, p-value = 1.534e-06
# alternative hypothesis: true location is greater than 60

# %% [markdown]
# # Q2. Difference in body weight between CI vs Normal? (Two-sample t-test)
# # group: 0 = normal, 1 = CI

# %%
library(dplyr)
library(ggplot2)

dat %>%
  group_by(group) %>%
  summarise(
    n       = n(),
    mean_wt = mean(weight, na.rm = TRUE),
    sd_wt   = sd(weight,   na.rm = TRUE)
  )
# Out:
#   group n   mean_wt  sd_wt
# 1 0     200 62.69400  9.232974
# 2 1     200 62.78975 12.411008

# %%
ggplot(dat, aes(x = factor(group), y = weight)) +
  geom_boxplot() +
  labs(x = "Group (0 = normal, 1 = CI)",
       y = "Body weight (kg)",
       title = "Body weight by group")
# Out:
# plot without title

# %%
#2. Normality & homogeneity of variance
by(dat$weight, dat$group, shapiro.test)
# Out:
# dat$group: 0
#
# 	Shapiro-Wilk normality test
#
# data:  dd[x, ]
# W = 0.97238, p-value = 0.0005611
#
# ------------------------------------------------------------
# dat$group: 1
#
# 	Shapiro-Wilk normality test
#
# data:  dd[x, ]
# W = 0.83249, p-value = 6.546e-14

# %%
# Homogeneity of variances: F-test (or Levene test)
var.test(weight ~ group, data = dat)
# Out:
# 	F test to compare two variances
#
# data:  weight by group
# F = 0.55344, num df = 199, denom df = 199, p-value = 3.506e-05
# alternative hypothesis: true ratio of variances is not equal to 1
# 95 percent confidence interval:
#  0.4188346 0.7313001
# sample estimates:
# ratio of variances
#          0.5534381

# %%
t.test(weight ~ group, data=dat, var.equal=TRUE)
# Out:
# 	Two Sample t-test
#
# data:  weight by group
# t = -0.087539, df = 398, p-value = 0.9303
# alternative hypothesis: true difference in means between group 0 and group 1 is not equal to 0
# 95 percent confidence interval:
#  -2.246103  2.054603
# sample estimates:
# mean in group 0 mean in group 1
#        62.69400        62.78975

# %%
t.test(weight ~ group, data=dat, var.equal=FALSE) #welch
# Out:
# 	Welch Two Sample t-test
#
# data:  weight by group
# t = -0.087539, df = 367.62, p-value = 0.9303
# alternative hypothesis: true difference in means between group 0 and group 1 is not equal to 0
# 95 percent confidence interval:
#  -2.246645  2.055145
# sample estimates:
# mean in group 0 mean in group 1
#        62.69400        62.78975

# %%
wilcox.test(weight ~ group, data=dat,alternative = "two.sided")
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  weight by group
# W = 19814, p-value = 0.8725
# alternative hypothesis: true location shift is not equal to 0

# %% [markdown]
# # Q3. Among CI patients, 3 drinking groups & HCT (ANOVA + post-hoc)
# # Subset data & convert to factor

# %%
# Extract CI patients only
dat_CI <- subset(dat, group == 1)

# %%
# Convert drinking to factor
dat_CI$drinking <- factor(dat_CI$drinking,
                          labels = c("Non-drinker", "Moderate", "Heavy"))

# %%
str(dat_CI$drinking)
# Out:
#  Factor w/ 3 levels "Non-drinker",..: 2 1 3 2 3 1 1 2 1 3 ...

# %%
# Descriptive summary & boxplot
dat_CI %>%
  group_by(drinking) %>%
  summarise(
    n       = n(),
    mean_HCT = mean(Hct, na.rm = TRUE),
    sd_HCT   = sd(Hct,   na.rm = TRUE)
  )
# Out:
#   drinking    n  mean_HCT sd_HCT
# 1 Non-drinker 95 39.48105 5.003090
# 2 Moderate    19 39.92105 3.218968
# 3 Heavy       86 41.91279 4.863158

# %%
ggplot(dat_CI, aes(x = drinking, y = Hct)) +
  geom_boxplot() +
  labs(x = "Drinking status",
       y = "HCT",
       title = "HCT by drinking status in CI patients")
# Out:
# plot without title

# %% [markdown]
# ## 2. Check ANOVA assumptions

# %%
#(1) Normality of residuals
fit_aov <- aov(Hct ~ drinking, data = dat_CI)

# %%
# Normality of residuals
par(mfrow = c(1, 2))
qqnorm(residuals(fit_aov)); qqline(residuals(fit_aov), col = 2)
hist(residuals(fit_aov), breaks = 20,
     main = "Histogram of residuals", xlab = "Residuals")
par(mfrow = c(1, 1))
# Out:
# Plot with title "Histogram of residuals"

# %%
shapiro.test(residuals(fit_aov))
# Out:
# 	Shapiro-Wilk normality test
#
# data:  residuals(fit_aov)
# W = 0.91728, p-value = 3.697e-09

# %%
library(car)
library(car)
leveneTest(Hct ~ drinking, data = dat_CI)
# Out:
#       Df  F value  Pr(>F)
# group   2 1.254072 0.2876082
#       197       NA        NA

# %%
# 3. One-way ANOVA
summary(fit_aov)
# Out:
#              Df Sum Sq Mean Sq F value  Pr(>F)
# drinking      2    276  137.86   5.969 0.00304 **
# Residuals   197   4550   23.09
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %%
#4. Post-hoc Multiple Comparison (Tukey)
TukeyHSD(fit_aov, "drinking", conf.level = 0.95)
# Out:
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = Hct ~ drinking, data = dat_CI)
#
# $drinking
#                          diff        lwr      upr     p adj
# Moderate-Non-drinker 0.440000 -2.4121457 3.292146 0.9294811
# Heavy-Non-drinker    2.431738  0.7425184 4.120958 0.0023456
# Heavy-Moderate       1.991738 -0.8851734 4.868650 0.2334144

# %%
#5.  If assumptions are violated:) Kruskal-Wallis + Dunn test

# Kruskal–Wallis test
kruskal.test(Hct ~ drinking, data = dat_CI)
# Out:
# 	Kruskal-Wallis rank sum test
#
# data:  Hct by drinking
# Kruskal-Wallis chi-squared = 12.981, df = 2, p-value = 0.001518

# %%
# Post-hoc Dunn test
# install.packages("FSA")
library(FSA)
dunnTest(Hct ~ drinking, data = dat_CI, method = "bonferroni")
# Out:
# Dunn (1964) Kruskal-Wallis multiple comparison
#
#   p-values adjusted with the Bonferroni method.
#               Comparison          Z      P.unadj       P.adj
# 1       Heavy - Moderate 1.95855325 0.0501651289 0.150495387
# 2    Heavy - Non-drinker 3.48041520 0.0005006373 0.001501912
# 3 Moderate - Non-drinker 0.08576054 0.9316567748 1.000000000
